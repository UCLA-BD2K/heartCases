# %% [markdown]
# First, import packages and declare functions to use later.

# %%
PMID_regex = r'PMID[- ]*?(\d+)'
abstract_regex = r'AB  - ([\s\S]*?)FAU'
mesh_terms_regex = r'\nMH[\s-]+([\w\-\*\,\/\ ]+)'

import re
import statistics
import operator
from apyori import apriori
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

def getMESHterms(medline, ignoreTerms = {}):
    # List of MeSH terms
    mesh_terms = re.findall(mesh_terms_regex, medline)
    toRemove = []
    for term in mesh_terms:
        if term in ignoreTerms:
            toRemove.append(term)
    for each in toRemove:
        mesh_terms.remove(each)
    for i in range(0, len(mesh_terms)):
        if re.search('(.+?)[\/,]', mesh_terms[i]):
            mesh_terms[i] = re.findall('(.+?)[\/,]', mesh_terms[i])[0]
    return mesh_terms

class PubMedCaseReport:
    def __init__(self, casereport, mesh=False, ab=False):
        self.pmid = int(re.search(PMID_regex, casereport)[1])
        self.MESH_terms = []
        if mesh:
            self.MESH_terms = getMESHterms(casereport)
        self.abstract = None
        if ab and re.search(abstract_regex, casereport):
            abstract = re.search(abstract_regex, casereport)[1]
            abstract = re.sub(r'\n', ' ', abstract)
            self.abstract = re.sub(r'\s{2,}', ' ', abstract)

# %% [markdown]
# Second, read in the ACCR case reports, gather up the MESH terms, how frequently they occur, and filter out the terms that appear "too often" or "too little".  Then we run the apriori algorithm on the MESH terms for the case reports and see what associations come up frequently, and narrow down the list to 2-term associations for the visualization.  Finally, we get a count of how many 2-item associations each MESH term in our whole set appears.

# %%
with open('ACCR.txt', 'r', encoding="utf8") as f:
    data = f.read()
f.close()

caseReports = data.split('\n\n')

mesh_terms = [getMESHterms(casereport) for casereport in caseReports]
pubmed_classes = [PubMedCaseReport(casereport, True) for casereport in caseReports]

term_counts = {}
for terms in mesh_terms:
    for term in terms:
        if term in term_counts:
            term_counts[term] += 1
        else:
            term_counts[term] = 1

count_distribution = []
for each in term_counts:
    count_distribution.append(term_counts[each])

avg_appearance = statistics.mean(count_distribution)
std_dev = statistics.stdev(count_distribution)
extreme_occurrance_terms = {}
for term in term_counts:
    if term_counts[term] > avg_appearance + 5*std_dev or term_counts[term] < avg_appearance:
        extreme_occurrance_terms[term] = term_counts[term]

filtered_mesh_terms = []
for report in caseReports:
    if getMESHterms(report, extreme_occurrance_terms):
        filtered_mesh_terms.append(getMESHterms(report, extreme_occurrance_terms))

results = list(apriori(filtered_mesh_terms, min_support = .005, min_lift = 1.5))
results_2x2 = [group for group in results if len(group.items) == 2]

frequency_counts = {}
for each in results_2x2:
    for term in each.items:
        if term in frequency_counts:
            frequency_counts[term] += 1
        else:
            frequency_counts[term] = 1
frequency_counts_sorted = sorted(frequency_counts.items(), key=operator.itemgetter(1), reverse=True)
print('Total MESH terms:', len(frequency_counts_sorted))
for each in frequency_counts_sorted:
    print(each[1], each[0])
# Out:
# Total MESH terms: 68
# 18 Echocardiography
# 12 Heart Failure
# 9 Tomography
# 9 Biopsy
# 8 Diagnosis
# 7 DNA
# 7 Carcinoma
# 6 Infant
# 6 Immunohistochemistry
# 6 Follow-Up Studies
# 5 DNA Mutational Analysis
# 5 Pedigree
# 5 Mutation
# 5 Muscle
# 5 Pregnancy
# 5 Cytochrome-c Oxidase Deficiency
# 4 Lung Neoplasms
# 4 Risk Assessment
# 4 Fatal Outcome
# 4 Coronary Angiography
# 4 Electrocardiography
# 4 Severity of Illness Index
# 3 Adolescent
# 3 Biomarkers
# 3 Electron Transport Complex IV
# 3 Ultrasonography
# 2 Mitochondria
# 2 *Mutation
# 2 Adenocarcinoma
# 2 Aged
# 2 Molecular Sequence Data
# 2 Aortic Valve Stenosis
# 2 Cardiomyopathy
# 2 Shock
# 2 Radiography
# 2 Ventricular Dysfunction
# 1 *Cytochrome-c Oxidase Deficiency
# 1 Abnormalities
# 1 Amino Acid Sequence
# 1 Base Sequence
# 1 Skin
# 1 Brain Neoplasms
# 1 Esophageal Neoplasms
# 1 Liver Neoplasms
# 1 Cardiac Catheterization
# 1 Cardiac Surgical Procedures
# 1 Cardiomyopathies
# 1 Cesarean Section
# 1 Myocardial Infarction
# 1 RNA
# 1 Dyspnea
# 1 Skin Diseases
# 1 Heart Septal Defects
# 1 Heart Valve Prosthesis Implantation
# 1 Heart Ventricles
# 1 Stroke Volume
# 1 Time Factors
# 1 Ventricular Function
# 1 Syndrome
# 1 Lung
# 1 Lung Diseases
# 1 Nevus
# 1 Skin Neoplasms
# 1 Phenotype
# 1 Pituitary Neoplasms
# 1 Prolactinoma
# 1 Pregnancy Complications
# 1 Pregnancy Trimester

# %% [markdown]
# Third, we look at associations with MESH terms that appear at least twice.

# %%
filtered_2x2_results = []
for each in results_2x2:
    add_association = True
    for term in each.items:
        if frequency_counts[term] < 2:
            add_association = False
            break
    if add_association:
        filtered_2x2_results.append(each)
    add_association = False
print(len(filtered_2x2_results))
# Out:
# 73

# %%
for each in filtered_2x2_results:
    print(each)
# Out:
# RelationRecord(items=frozenset({'DNA Mutational Analysis', '*Mutation'}), support=0.005697050938337802, ordered_statistics=[OrderedStatistic(items_base=frozenset({'*Mutation'}), items_add=frozenset({'DNA Mutational Analysis'}), confidence=0.2741935483870968, lift=12.396871945259043), OrderedStatistic(items_base=frozenset({'DNA Mutational Analysis'}), items_add=frozenset({'*Mutation'}), confidence=0.25757575757575757, lift=12.396871945259042)])
# RelationRecord(items=frozenset({'Pedigree', '*Mutation'}), support=0.005697050938337802, ordered_statistics=[OrderedStatistic(items_base=frozenset({'*Mutation'}), items_add=frozenset({'Pedigree'}), confidence=0.2741935483870968, lift=10.909247311827958), OrderedStatistic(items_base=frozenset({'Pedigree'}), items_add=frozenset({'*Mutation'}), confidence=0.22666666666666668, lift=10.909247311827958)])
# RelationRecord(items=frozenset({'Adenocarcinoma', 'Lung Neoplasms'}), support=0.0070375335120643435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Adenocarcinoma'}), items_add=frozenset({'Lung Neoplasms'}), confidence=0.33870967741935487, lift=9.812715314751019), OrderedStatistic(items_base=frozenset({'Lung Neoplasms'}), items_add=frozenset({'Adenocarcinoma'}), confidence=0.20388349514563106, lift=9.812715314751017)])
# RelationRecord(items=frozenset({'Adenocarcinoma', 'Tomography'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Adenocarcinoma'}), items_add=frozenset({'Tomography'}), confidence=0.24193548387096775, lift=2.2702373706634207), OrderedStatistic(items_base=frozenset({'Tomography'}), items_add=frozenset({'Adenocarcinoma'}), confidence=0.04716981132075471, lift=2.2702373706634202)])
# RelationRecord(items=frozenset({'Adolescent', 'DNA'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Adolescent'}), items_add=frozenset({'DNA'}), confidence=0.07246376811594202, lift=2.514324233232221), OrderedStatistic(items_base=frozenset({'DNA'}), items_add=frozenset({'Adolescent'}), confidence=0.1744186046511628, lift=2.514324233232221)])
# RelationRecord(items=frozenset({'Mutation', 'Adolescent'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Adolescent'}), items_add=frozenset({'Mutation'}), confidence=0.07246376811594202, lift=1.7579827972192763), OrderedStatistic(items_base=frozenset({'Mutation'}), items_add=frozenset({'Adolescent'}), confidence=0.12195121951219512, lift=1.7579827972192763)])
# RelationRecord(items=frozenset({'Adolescent', 'Pedigree'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Adolescent'}), items_add=frozenset({'Pedigree'}), confidence=0.07246376811594202, lift=2.8830917874396134), OrderedStatistic(items_base=frozenset({'Pedigree'}), items_add=frozenset({'Adolescent'}), confidence=0.2, lift=2.8830917874396134)])
# RelationRecord(items=frozenset({'Aged', 'Heart Failure'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aged'}), items_add=frozenset({'Heart Failure'}), confidence=0.17045454545454547, lift=2.343946376204441), OrderedStatistic(items_base=frozenset({'Heart Failure'}), items_add=frozenset({'Aged'}), confidence=0.06912442396313363, lift=2.3439463762044404)])
# RelationRecord(items=frozenset({'Aged', 'Tomography'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aged'}), items_add=frozenset({'Tomography'}), confidence=0.17045454545454547, lift=1.5994854202401374), OrderedStatistic(items_base=frozenset({'Tomography'}), items_add=frozenset({'Aged'}), confidence=0.04716981132075471, lift=1.5994854202401372)])
# RelationRecord(items=frozenset({'Aortic Valve Stenosis', 'Echocardiography'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aortic Valve Stenosis'}), items_add=frozenset({'Echocardiography'}), confidence=0.625, lift=8.438914027149321), OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Aortic Valve Stenosis'}), confidence=0.0904977375565611, lift=8.438914027149321)])
# RelationRecord(items=frozenset({'Aortic Valve Stenosis', 'Heart Failure'}), support=0.007707774798927614, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Aortic Valve Stenosis'}), items_add=frozenset({'Heart Failure'}), confidence=0.71875, lift=9.883640552995391), OrderedStatistic(items_base=frozenset({'Heart Failure'}), items_add=frozenset({'Aortic Valve Stenosis'}), confidence=0.10599078341013823, lift=9.88364055299539)])
# RelationRecord(items=frozenset({'Biopsy', 'Biomarkers'}), support=0.006032171581769437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biomarkers'}), items_add=frozenset({'Biopsy'}), confidence=0.2647058823529411, lift=3.815856777493605), OrderedStatistic(items_base=frozenset({'Biopsy'}), items_add=frozenset({'Biomarkers'}), confidence=0.08695652173913042, lift=3.815856777493605)])
# RelationRecord(items=frozenset({'Biomarkers', 'Carcinoma'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biomarkers'}), items_add=frozenset({'Carcinoma'}), confidence=0.22058823529411764, lift=4.274255156608097), OrderedStatistic(items_base=frozenset({'Carcinoma'}), items_add=frozenset({'Biomarkers'}), confidence=0.09740259740259741, lift=4.274255156608098)])
# RelationRecord(items=frozenset({'Biomarkers', 'Immunohistochemistry'}), support=0.00871313672922252, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biomarkers'}), items_add=frozenset({'Immunohistochemistry'}), confidence=0.3823529411764706, lift=10.00825593395253), OrderedStatistic(items_base=frozenset({'Immunohistochemistry'}), items_add=frozenset({'Biomarkers'}), confidence=0.22807017543859653, lift=10.00825593395253)])
# RelationRecord(items=frozenset({'Biopsy', 'Carcinoma'}), support=0.00804289544235925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biopsy'}), items_add=frozenset({'Carcinoma'}), confidence=0.11594202898550725, lift=2.2465650291737247), OrderedStatistic(items_base=frozenset({'Carcinoma'}), items_add=frozenset({'Biopsy'}), confidence=0.15584415584415584, lift=2.2465650291737247)])
# RelationRecord(items=frozenset({'Biopsy', 'Diagnosis'}), support=0.018096514745308313, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biopsy'}), items_add=frozenset({'Diagnosis'}), confidence=0.2608695652173913, lift=1.946086956521739), OrderedStatistic(items_base=frozenset({'Diagnosis'}), items_add=frozenset({'Biopsy'}), confidence=0.135, lift=1.9460869565217391)])
# RelationRecord(items=frozenset({'Biopsy', 'Follow-Up Studies'}), support=0.011058981233243968, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biopsy'}), items_add=frozenset({'Follow-Up Studies'}), confidence=0.15942028985507245, lift=3.3266443701226307), OrderedStatistic(items_base=frozenset({'Follow-Up Studies'}), items_add=frozenset({'Biopsy'}), confidence=0.23076923076923078, lift=3.326644370122631)])
# RelationRecord(items=frozenset({'Biopsy', 'Immunohistochemistry'}), support=0.017761394101876677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biopsy'}), items_add=frozenset({'Immunohistochemistry'}), confidence=0.2560386473429952, lift=6.701923891855243), OrderedStatistic(items_base=frozenset({'Immunohistochemistry'}), items_add=frozenset({'Biopsy'}), confidence=0.46491228070175444, lift=6.701923891855242)])
# RelationRecord(items=frozenset({'Biopsy', 'Muscle'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biopsy'}), items_add=frozenset({'Muscle'}), confidence=0.0966183574879227, lift=4.1187025534851625), OrderedStatistic(items_base=frozenset({'Muscle'}), items_add=frozenset({'Biopsy'}), confidence=0.28571428571428575, lift=4.1187025534851625)])
# RelationRecord(items=frozenset({'Biopsy', 'Risk Assessment'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biopsy'}), items_add=frozenset({'Risk Assessment'}), confidence=0.0966183574879227, lift=5.653121151842379), OrderedStatistic(items_base=frozenset({'Risk Assessment'}), items_add=frozenset({'Biopsy'}), confidence=0.39215686274509803, lift=5.653121151842379)])
# RelationRecord(items=frozenset({'Biopsy', 'Tomography'}), support=0.014745308310991957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Biopsy'}), items_add=frozenset({'Tomography'}), confidence=0.21256038647342992, lift=1.9945918026311789), OrderedStatistic(items_base=frozenset({'Tomography'}), items_add=frozenset({'Biopsy'}), confidence=0.13836477987421383, lift=1.994591802631179)])
# RelationRecord(items=frozenset({'Fatal Outcome', 'Carcinoma'}), support=0.0070375335120643435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Carcinoma'}), items_add=frozenset({'Fatal Outcome'}), confidence=0.13636363636363638, lift=2.09746954076851), OrderedStatistic(items_base=frozenset({'Fatal Outcome'}), items_add=frozenset({'Carcinoma'}), confidence=0.10824742268041238, lift=2.0974695407685098)])
# RelationRecord(items=frozenset({'Immunohistochemistry', 'Carcinoma'}), support=0.006367292225201072, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Carcinoma'}), items_add=frozenset({'Immunohistochemistry'}), confidence=0.12337662337662338, lift=3.2294372294372296), OrderedStatistic(items_base=frozenset({'Immunohistochemistry'}), items_add=frozenset({'Carcinoma'}), confidence=0.16666666666666669, lift=3.22943722943723)])
# RelationRecord(items=frozenset({'Carcinoma', 'Lung Neoplasms'}), support=0.012399463806970509, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Carcinoma'}), items_add=frozenset({'Lung Neoplasms'}), confidence=0.24025974025974026, lift=6.960534611020047), OrderedStatistic(items_base=frozenset({'Lung Neoplasms'}), items_add=frozenset({'Carcinoma'}), confidence=0.35922330097087374, lift=6.960534611020047)])
# RelationRecord(items=frozenset({'Cardiomyopathy', 'Echocardiography'}), support=0.007707774798927614, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cardiomyopathy'}), items_add=frozenset({'Echocardiography'}), confidence=0.28048780487804875, lift=3.7872199536475004), OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Cardiomyopathy'}), confidence=0.10407239819004525, lift=3.7872199536475004)])
# RelationRecord(items=frozenset({'Cardiomyopathy', 'Heart Failure'}), support=0.006032171581769437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cardiomyopathy'}), items_add=frozenset({'Heart Failure'}), confidence=0.2195121951219512, lift=3.01854557716084), OrderedStatistic(items_base=frozenset({'Heart Failure'}), items_add=frozenset({'Cardiomyopathy'}), confidence=0.08294930875576036, lift=3.01854557716084)])
# RelationRecord(items=frozenset({'Coronary Angiography', 'Echocardiography'}), support=0.011058981233243968, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coronary Angiography'}), items_add=frozenset({'Echocardiography'}), confidence=0.5076923076923077, lift=6.854994778976679), OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Coronary Angiography'}), confidence=0.14932126696832582, lift=6.85499477897668)])
# RelationRecord(items=frozenset({'Electrocardiography', 'Coronary Angiography'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coronary Angiography'}), items_add=frozenset({'Electrocardiography'}), confidence=0.3076923076923077, lift=9.001508295625943), OrderedStatistic(items_base=frozenset({'Electrocardiography'}), items_add=frozenset({'Coronary Angiography'}), confidence=0.19607843137254902, lift=9.001508295625943)])
# RelationRecord(items=frozenset({'Coronary Angiography', 'Shock'}), support=0.006032171581769437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coronary Angiography'}), items_add=frozenset({'Shock'}), confidence=0.2769230769230769, lift=21.74574898785425), OrderedStatistic(items_base=frozenset({'Shock'}), items_add=frozenset({'Coronary Angiography'}), confidence=0.47368421052631576, lift=21.74574898785425)])
# RelationRecord(items=frozenset({'DNA', 'Cytochrome-c Oxidase Deficiency'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cytochrome-c Oxidase Deficiency'}), items_add=frozenset({'DNA'}), confidence=0.33898305084745767, lift=11.761923531730393), OrderedStatistic(items_base=frozenset({'DNA'}), items_add=frozenset({'Cytochrome-c Oxidase Deficiency'}), confidence=0.23255813953488375, lift=11.761923531730393)])
# RelationRecord(items=frozenset({'DNA Mutational Analysis', 'Cytochrome-c Oxidase Deficiency'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cytochrome-c Oxidase Deficiency'}), items_add=frozenset({'DNA Mutational Analysis'}), confidence=0.2542372881355932, lift=11.494607087827426), OrderedStatistic(items_base=frozenset({'DNA Mutational Analysis'}), items_add=frozenset({'Cytochrome-c Oxidase Deficiency'}), confidence=0.22727272727272727, lift=11.494607087827427)])
# RelationRecord(items=frozenset({'Electron Transport Complex IV', 'Cytochrome-c Oxidase Deficiency'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cytochrome-c Oxidase Deficiency'}), items_add=frozenset({'Electron Transport Complex IV'}), confidence=0.33898305084745767, lift=21.98968312453943), OrderedStatistic(items_base=frozenset({'Electron Transport Complex IV'}), items_add=frozenset({'Cytochrome-c Oxidase Deficiency'}), confidence=0.43478260869565216, lift=21.989683124539425)])
# RelationRecord(items=frozenset({'Mitochondria', 'Cytochrome-c Oxidase Deficiency'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cytochrome-c Oxidase Deficiency'}), items_add=frozenset({'Mitochondria'}), confidence=0.2542372881355932, lift=12.858374030451019), OrderedStatistic(items_base=frozenset({'Mitochondria'}), items_add=frozenset({'Cytochrome-c Oxidase Deficiency'}), confidence=0.2542372881355932, lift=12.858374030451019)])
# RelationRecord(items=frozenset({'Muscle', 'Cytochrome-c Oxidase Deficiency'}), support=0.006032171581769437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cytochrome-c Oxidase Deficiency'}), items_add=frozenset({'Muscle'}), confidence=0.3050847457627119, lift=13.005326876513319), OrderedStatistic(items_base=frozenset({'Muscle'}), items_add=frozenset({'Cytochrome-c Oxidase Deficiency'}), confidence=0.2571428571428572, lift=13.005326876513319)])
# RelationRecord(items=frozenset({'DNA Mutational Analysis', 'DNA'}), support=0.005026809651474531, ordered_statistics=[OrderedStatistic(items_base=frozenset({'DNA'}), items_add=frozenset({'DNA Mutational Analysis'}), confidence=0.1744186046511628, lift=7.885835095137421), OrderedStatistic(items_base=frozenset({'DNA Mutational Analysis'}), items_add=frozenset({'DNA'}), confidence=0.22727272727272727, lift=7.885835095137421)])
# RelationRecord(items=frozenset({'Electron Transport Complex IV', 'DNA'}), support=0.006032171581769437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'DNA'}), items_add=frozenset({'Electron Transport Complex IV'}), confidence=0.20930232558139536, lift=13.577350859453995), OrderedStatistic(items_base=frozenset({'Electron Transport Complex IV'}), items_add=frozenset({'DNA'}), confidence=0.3913043478260869, lift=13.577350859453993)])
# RelationRecord(items=frozenset({'Muscle', 'DNA'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'DNA'}), items_add=frozenset({'Muscle'}), confidence=0.23255813953488375, lift=9.913621262458474), OrderedStatistic(items_base=frozenset({'Muscle'}), items_add=frozenset({'DNA'}), confidence=0.28571428571428575, lift=9.913621262458474)])
# RelationRecord(items=frozenset({'Mutation', 'DNA'}), support=0.006032171581769437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'DNA'}), items_add=frozenset({'Mutation'}), confidence=0.20930232558139536, lift=5.07770845150312), OrderedStatistic(items_base=frozenset({'Mutation'}), items_add=frozenset({'DNA'}), confidence=0.14634146341463414, lift=5.07770845150312)])
# RelationRecord(items=frozenset({'DNA Mutational Analysis', 'Mutation'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'DNA Mutational Analysis'}), items_add=frozenset({'Mutation'}), confidence=0.30303030303030304, lift=7.351564424735157), OrderedStatistic(items_base=frozenset({'Mutation'}), items_add=frozenset({'DNA Mutational Analysis'}), confidence=0.16260162601626016, lift=7.351564424735156)])
# RelationRecord(items=frozenset({'DNA Mutational Analysis', 'Pedigree'}), support=0.005361930294906166, ordered_statistics=[OrderedStatistic(items_base=frozenset({'DNA Mutational Analysis'}), items_add=frozenset({'Pedigree'}), confidence=0.24242424242424243, lift=9.645252525252525), OrderedStatistic(items_base=frozenset({'Pedigree'}), items_add=frozenset({'DNA Mutational Analysis'}), confidence=0.21333333333333335, lift=9.645252525252525)])
# RelationRecord(items=frozenset({'Diagnosis', 'Echocardiography'}), support=0.01675603217158177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Diagnosis'}), items_add=frozenset({'Echocardiography'}), confidence=0.125, lift=1.6877828054298645), OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Diagnosis'}), confidence=0.22624434389140274, lift=1.6877828054298645)])
# RelationRecord(items=frozenset({'Electrocardiography', 'Diagnosis'}), support=0.0070375335120643435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Diagnosis'}), items_add=frozenset({'Electrocardiography'}), confidence=0.0525, lift=1.5358823529411763), OrderedStatistic(items_base=frozenset({'Electrocardiography'}), items_add=frozenset({'Diagnosis'}), confidence=0.20588235294117646, lift=1.5358823529411763)])
# RelationRecord(items=frozenset({'Diagnosis', 'Radiography'}), support=0.013739946380697051, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Diagnosis'}), items_add=frozenset({'Radiography'}), confidence=0.1025, lift=1.948152866242038), OrderedStatistic(items_base=frozenset({'Radiography'}), items_add=frozenset({'Diagnosis'}), confidence=0.2611464968152866, lift=1.9481528662420382)])
# RelationRecord(items=frozenset({'Diagnosis', 'Tomography'}), support=0.024463806970509382, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Diagnosis'}), items_add=frozenset({'Tomography'}), confidence=0.1825, lift=1.7125157232704402), OrderedStatistic(items_base=frozenset({'Tomography'}), items_add=frozenset({'Diagnosis'}), confidence=0.22955974842767293, lift=1.71251572327044)])
# RelationRecord(items=frozenset({'Electrocardiography', 'Echocardiography'}), support=0.011729222520107238, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Electrocardiography'}), confidence=0.1583710407239819, lift=4.63312926980747), OrderedStatistic(items_base=frozenset({'Electrocardiography'}), items_add=frozenset({'Echocardiography'}), confidence=0.34313725490196073, lift=4.63312926980747)])
# RelationRecord(items=frozenset({'Fatal Outcome', 'Echocardiography'}), support=0.007707774798927614, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Fatal Outcome'}), confidence=0.10407239819004525, lift=1.6007836917479126), OrderedStatistic(items_base=frozenset({'Fatal Outcome'}), items_add=frozenset({'Echocardiography'}), confidence=0.11855670103092783, lift=1.6007836917479126)])
# RelationRecord(items=frozenset({'Follow-Up Studies', 'Echocardiography'}), support=0.00804289544235925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Follow-Up Studies'}), confidence=0.10859728506787332, lift=2.2661139765212166), OrderedStatistic(items_base=frozenset({'Follow-Up Studies'}), items_add=frozenset({'Echocardiography'}), confidence=0.16783216783216784, lift=2.2661139765212166)])
# RelationRecord(items=frozenset({'Heart Failure', 'Echocardiography'}), support=0.022453083109919572, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Heart Failure'}), confidence=0.30316742081447967, lift=4.1689013074212316), OrderedStatistic(items_base=frozenset({'Heart Failure'}), items_add=frozenset({'Echocardiography'}), confidence=0.3087557603686636, lift=4.1689013074212316)])
# RelationRecord(items=frozenset({'Infant', 'Echocardiography'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Infant'}), confidence=0.0904977375565611, lift=1.8123842205958276), OrderedStatistic(items_base=frozenset({'Infant'}), items_add=frozenset({'Echocardiography'}), confidence=0.1342281879194631, lift=1.8123842205958276)])
# RelationRecord(items=frozenset({'Radiography', 'Echocardiography'}), support=0.006367292225201072, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Radiography'}), confidence=0.08597285067873303, lift=1.6340317606709513), OrderedStatistic(items_base=frozenset({'Radiography'}), items_add=frozenset({'Echocardiography'}), confidence=0.12101910828025478, lift=1.6340317606709516)])
# RelationRecord(items=frozenset({'Severity of Illness Index', 'Echocardiography'}), support=0.007372654155495978, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Severity of Illness Index'}), confidence=0.0995475113122172, lift=4.243568196509374), OrderedStatistic(items_base=frozenset({'Severity of Illness Index'}), items_add=frozenset({'Echocardiography'}), confidence=0.3142857142857143, lift=4.243568196509373)])
# RelationRecord(items=frozenset({'Shock', 'Echocardiography'}), support=0.0070375335120643435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Shock'}), confidence=0.09502262443438915, lift=7.461776613479401), OrderedStatistic(items_base=frozenset({'Shock'}), items_add=frozenset({'Echocardiography'}), confidence=0.5526315789473685, lift=7.461776613479401)])
# RelationRecord(items=frozenset({'Ventricular Dysfunction', 'Echocardiography'}), support=0.005361930294906166, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Echocardiography'}), items_add=frozenset({'Ventricular Dysfunction'}), confidence=0.07239819004524888, lift=4.5965148743621835), OrderedStatistic(items_base=frozenset({'Ventricular Dysfunction'}), items_add=frozenset({'Echocardiography'}), confidence=0.3404255319148936, lift=4.5965148743621835)])
# RelationRecord(items=frozenset({'Electrocardiography', 'Heart Failure'}), support=0.0070375335120643435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Electrocardiography'}), items_add=frozenset({'Heart Failure'}), confidence=0.20588235294117646, lift=2.83111954459203), OrderedStatistic(items_base=frozenset({'Heart Failure'}), items_add=frozenset({'Electrocardiography'}), confidence=0.0967741935483871, lift=2.8311195445920303)])
# RelationRecord(items=frozenset({'Electron Transport Complex IV', 'Muscle'}), support=0.005361930294906166, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Electron Transport Complex IV'}), items_add=frozenset({'Muscle'}), confidence=0.34782608695652173, lift=14.827329192546584), OrderedStatistic(items_base=frozenset({'Muscle'}), items_add=frozenset({'Electron Transport Complex IV'}), confidence=0.2285714285714286, lift=14.827329192546586)])
# RelationRecord(items=frozenset({'Fatal Outcome', 'Infant'}), support=0.0070375335120643435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fatal Outcome'}), items_add=frozenset({'Infant'}), confidence=0.10824742268041238, lift=2.1678544246869165), OrderedStatistic(items_base=frozenset({'Infant'}), items_add=frozenset({'Fatal Outcome'}), confidence=0.14093959731543626, lift=2.1678544246869165)])
# RelationRecord(items=frozenset({'Fatal Outcome', 'Lung Neoplasms'}), support=0.005697050938337802, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fatal Outcome'}), items_add=frozenset({'Lung Neoplasms'}), confidence=0.08762886597938145, lift=2.538684816334701), OrderedStatistic(items_base=frozenset({'Lung Neoplasms'}), items_add=frozenset({'Fatal Outcome'}), confidence=0.1650485436893204, lift=2.538684816334701)])
# RelationRecord(items=frozenset({'Follow-Up Studies', 'Heart Failure'}), support=0.005697050938337802, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Follow-Up Studies'}), items_add=frozenset({'Heart Failure'}), confidence=0.1188811188811189, lift=1.6347523444297638), OrderedStatistic(items_base=frozenset({'Heart Failure'}), items_add=frozenset({'Follow-Up Studies'}), confidence=0.07834101382488479, lift=1.6347523444297638)])
# RelationRecord(items=frozenset({'Immunohistochemistry', 'Follow-Up Studies'}), support=0.00804289544235925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Follow-Up Studies'}), items_add=frozenset({'Immunohistochemistry'}), confidence=0.16783216783216784, lift=4.393080603606919), OrderedStatistic(items_base=frozenset({'Immunohistochemistry'}), items_add=frozenset({'Follow-Up Studies'}), confidence=0.2105263157894737, lift=4.39308060360692)])
# RelationRecord(items=frozenset({'Risk Assessment', 'Follow-Up Studies'}), support=0.01306970509383378, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Follow-Up Studies'}), items_add=frozenset({'Risk Assessment'}), confidence=0.27272727272727276, lift=15.9572192513369), OrderedStatistic(items_base=frozenset({'Risk Assessment'}), items_add=frozenset({'Follow-Up Studies'}), confidence=0.7647058823529411, lift=15.957219251336898)])
# RelationRecord(items=frozenset({'Follow-Up Studies', 'Severity of Illness Index'}), support=0.007707774798927614, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Follow-Up Studies'}), items_add=frozenset({'Severity of Illness Index'}), confidence=0.16083916083916086, lift=6.8563436563436575), OrderedStatistic(items_base=frozenset({'Severity of Illness Index'}), items_add=frozenset({'Follow-Up Studies'}), confidence=0.32857142857142857, lift=6.856343656343657)])
# RelationRecord(items=frozenset({'Severity of Illness Index', 'Heart Failure'}), support=0.0070375335120643435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Heart Failure'}), items_add=frozenset({'Severity of Illness Index'}), confidence=0.0967741935483871, lift=4.1253456221198155), OrderedStatistic(items_base=frozenset({'Severity of Illness Index'}), items_add=frozenset({'Heart Failure'}), confidence=0.30000000000000004, lift=4.1253456221198155)])
# RelationRecord(items=frozenset({'Ventricular Dysfunction', 'Heart Failure'}), support=0.008378016085790885, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Heart Failure'}), items_add=frozenset({'Ventricular Dysfunction'}), confidence=0.1152073732718894, lift=7.31444259241102), OrderedStatistic(items_base=frozenset({'Ventricular Dysfunction'}), items_add=frozenset({'Heart Failure'}), confidence=0.5319148936170213, lift=7.3144425924110195)])
# RelationRecord(items=frozenset({'Immunohistochemistry', 'Risk Assessment'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Immunohistochemistry'}), items_add=frozenset({'Risk Assessment'}), confidence=0.1754385964912281, lift=10.264877880976952), OrderedStatistic(items_base=frozenset({'Risk Assessment'}), items_add=frozenset({'Immunohistochemistry'}), confidence=0.39215686274509803, lift=10.264877880976952)])
# RelationRecord(items=frozenset({'Immunohistochemistry', 'Tomography'}), support=0.007372654155495978, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Immunohistochemistry'}), items_add=frozenset({'Tomography'}), confidence=0.1929824561403509, lift=1.810879399757255), OrderedStatistic(items_base=frozenset({'Tomography'}), items_add=frozenset({'Immunohistochemistry'}), confidence=0.06918238993710692, lift=1.8108793997572548)])
# RelationRecord(items=frozenset({'Pregnancy', 'Infant'}), support=0.010723860589812333, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Infant'}), items_add=frozenset({'Pregnancy'}), confidence=0.21476510067114096, lift=4.85499288183852), OrderedStatistic(items_base=frozenset({'Pregnancy'}), items_add=frozenset({'Infant'}), confidence=0.24242424242424243, lift=4.85499288183852)])
# RelationRecord(items=frozenset({'Ultrasonography', 'Infant'}), support=0.006032171581769437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Infant'}), items_add=frozenset({'Ultrasonography'}), confidence=0.12080536912751677, lift=3.1621335217237725), OrderedStatistic(items_base=frozenset({'Ultrasonography'}), items_add=frozenset({'Infant'}), confidence=0.15789473684210525, lift=3.1621335217237725)])
# RelationRecord(items=frozenset({'Tomography', 'Lung Neoplasms'}), support=0.009048257372654156, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lung Neoplasms'}), items_add=frozenset({'Tomography'}), confidence=0.2621359223300971, lift=2.4597911705440554), OrderedStatistic(items_base=frozenset({'Tomography'}), items_add=frozenset({'Lung Neoplasms'}), confidence=0.0849056603773585, lift=2.459791170544056)])
# RelationRecord(items=frozenset({'Mutation', 'Muscle'}), support=0.005697050938337802, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Muscle'}), items_add=frozenset({'Mutation'}), confidence=0.24285714285714288, lift=5.891753774680605), OrderedStatistic(items_base=frozenset({'Mutation'}), items_add=frozenset({'Muscle'}), confidence=0.13821138211382114, lift=5.891753774680605)])
# RelationRecord(items=frozenset({'Mutation', 'Pedigree'}), support=0.006702412868632708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mutation'}), items_add=frozenset({'Pedigree'}), confidence=0.16260162601626016, lift=6.469376693766938), OrderedStatistic(items_base=frozenset({'Pedigree'}), items_add=frozenset({'Mutation'}), confidence=0.26666666666666666, lift=6.469376693766938)])
# RelationRecord(items=frozenset({'Pregnancy', 'Ultrasonography'}), support=0.006367292225201072, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pregnancy'}), items_add=frozenset({'Ultrasonography'}), confidence=0.14393939393939392, lift=3.7676767676767673), OrderedStatistic(items_base=frozenset({'Ultrasonography'}), items_add=frozenset({'Pregnancy'}), confidence=0.16666666666666669, lift=3.7676767676767677)])
# RelationRecord(items=frozenset({'Risk Assessment', 'Severity of Illness Index'}), support=0.00804289544235925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Risk Assessment'}), items_add=frozenset({'Severity of Illness Index'}), confidence=0.47058823529411764, lift=20.060504201680672), OrderedStatistic(items_base=frozenset({'Severity of Illness Index'}), items_add=frozenset({'Risk Assessment'}), confidence=0.3428571428571429, lift=20.060504201680676)])
# RelationRecord(items=frozenset({'Ultrasonography', 'Tomography'}), support=0.006367292225201072, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tomography'}), items_add=frozenset({'Ultrasonography'}), confidence=0.059748427672955975, lift=1.5639412997903566), OrderedStatistic(items_base=frozenset({'Ultrasonography'}), items_add=frozenset({'Tomography'}), confidence=0.16666666666666669, lift=1.5639412997903566)])

# %% [markdown]
# ### Heatmap for Confidence

# %%
mesh_terms = [term for term in frequency_counts if frequency_counts[term] > 1]
association_confidence = pd.DataFrame(index=mesh_terms, columns=mesh_terms)
association_confidence = association_confidence.fillna(0) # with 0s rather than NaNs
for term in mesh_terms:
    association_confidence.loc[term, term] = 1
for result in filtered_2x2_results:
    for ordered_stat in result.ordered_statistics:
        base = list(ordered_stat.items_base)[0]
        add = list(ordered_stat.items_add)[0]
        association_confidence.loc[base, add] = ordered_stat.confidence

f, ax = plt.subplots(figsize=(15, 12))
hm_confidence = sns.heatmap(association_confidence, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t_confidence = f.suptitle('MESH Terms Confidence Heatmap', fontsize=24)
f.savefig('MESH_confidence.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Heatmap for Lift

# %%
association_lift = pd.DataFrame(index=mesh_terms, columns=mesh_terms)
association_lift = association_lift.fillna(0)
for term in mesh_terms:
    association_lift.loc[term, term] = 0
for result in filtered_2x2_results:
    for ordered_stat in result.ordered_statistics:
        base = list(ordered_stat.items_base)[0]
        add = list(ordered_stat.items_add)[0]
        association_lift.loc[base, add] = ordered_stat.lift

g, ax = plt.subplots(figsize=(15, 12))
hm_lift = sns.heatmap(association_lift, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
g.subplots_adjust(top=0.93)
t_lift = g.suptitle('MESH Terms Lift Heatmap', fontsize=24)
plt.show()
g.savefig('MESH_lift.png', dpi=300, bbox_inches='tight')
